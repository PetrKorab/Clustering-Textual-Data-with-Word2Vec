# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from nltk.corpus import stopwords
import re

# %%
data = pd.read_excel('corona_news_adj.xlsx')
data
# Out:
#                                                     title
# 0       British coronavirus evacuee who was 'taken ill...
# 1       CDC files for emergency approval of its corona...
# 2       Can ANY face mask really protect you from the ...
# 3       Experts: You won't catch coronavirus from pack...
# 4       Seventh American diagnosed with coronavirus as...
# ...                                                   ...
# 161649  Why have deaths stayed steady while infections...
# 161650  Trump says three novel coronavirus vaccine can...
# 161651  Coronavirus: Trump touts response as COVID-19 ...
# 161652  Woman, 21, 'attacked five airline ticketing ag...
# 161653  Why Morehouse and Clemson Made Different Footb...
#
# [161654 rows x 1 columns]

# %%
def preprocess(text):
    text_input = re.sub('[^a-zA-Z1-9]+', ' ', str(text))
    output = re.sub(r'\d+', '',text_input)
    return output.lower().strip()

data['title'] = data.title.map(preprocess)
data
# Out:
#                                                     title
# 0       british coronavirus evacuee who was taken ill ...
# 1       cdc files for emergency approval of its corona...
# 2       can any face mask really protect you from the ...
# 3       experts you won t catch coronavirus from packa...
# 4       seventh american diagnosed with coronavirus as...
# ...                                                   ...
# 161649  why have deaths stayed steady while infections...
# 161650  trump says three novel coronavirus vaccine can...
# 161651  coronavirus trump touts response as covid  dai...
# 161652  woman  attacked five airline ticketing agents ...
# 161653  why morehouse and clemson made different footb...
#
# [161654 rows x 1 columns]

# %%
stop = set(stopwords.words("english"))

def remove_stopwords(text):
    filtered_words = [word.lower() for word in text.split() if word.lower() not in stop]
    return " ".join(filtered_words)

data['title'] = data.title.map(remove_stopwords)
data
# Out:
#                                                     title
# 0       british coronavirus evacuee taken ill last fli...
# 1           cdc files emergency approval coronavirus test
# 2                    face mask really protect coronavirus
# 3                experts catch coronavirus packages china
# 4       seventh american diagnosed coronavirus us decl...
# ...                                                   ...
# 161649            deaths stayed steady infections spiking
# 161650  trump says three novel coronavirus vaccine can...
# 161651  coronavirus trump touts response covid daily c...
# 161652  woman attacked five airline ticketing agents c...
# 161653  morehouse clemson made different football choices
#
# [161654 rows x 1 columns]

# %%
def build_corpus(data):
    corpus = []
    for sentence in data.iteritems():
        word_list = sentence[1].split(" ")
        corpus.append(word_list)
    return corpus

corpus = build_corpus(data['title'])
# Out:
# [['british',
#   'coronavirus',
#   'evacuee',
#   'taken',
#   'ill',
#   'last',
#   'flight',
#   'wuhan'],
#  ['cdc', 'files', 'emergency', 'approval', 'coronavirus', 'test'],
#  ['face', 'mask', 'really', 'protect', 'coronavirus'],
#  ['experts', 'catch', 'coronavirus', 'packages', 'china'],
#  ['seventh',
#   'american',
#   'diagnosed',
#   'coronavirus',
#   'us',
#   'declares',
#   'public',
#   'health',
#   'emergency'],
#  ['rep',
#   'paul',
#   'gosar',
#   'coronavirus',
#   'save',
#   'lives',
#   'must',
#   'restrict',
#   'travel',
#   'affected',
#   'areas',
#   'us'],
#  ['cambodian',
#   'pm',
#   'says',
#   'visit',
#   'students',
#   'china',
#   'wuhan',
#   'moral',
#   'support'],
#  ['burdened',
#   'sanctions',
#   'north',
#   'korea',
#   'sees',
#   'coronavirus',
#   'threaten',
#   'economic',
#   'lifelines'],
#  ['two', 'coronavirus', 'cases', 'confirmed', 'uk'],
#  ['coronavirus', 'worldwide', 'cases', 'surpass', 'sars', 'outbreak'],
#  ['coronavirus', 'catching', 'diseases', 'animals'],
#  ['coronavirus',
#   'cement',
#   'mixers',
#   'become',
#   'celebrities',
#   'china',
#   'lockdown'],
#  ['coronavirus', 'wuhan', 'diary', 'living', 'alone', 'city', 'gone', 'quiet'],
#  ['coronavirus', 'declared', 'global', 'health', 'emergency'],
#  ['coronavirus',
#   'death',
#   'toll',
#   'rises',
#   'virus',
#   'spreads',
#   'every',
#   'chinese',
#   'region'],
#  ['coronavirus', 'quarantine', 'mean'],
#  ['coronavirus', 'scientists', 'race', 'develop', 'vaccine'],
#  ['coronavirus', 'us', 'laboratory', 'developing', 'vaccine'],
#  ['wuhan', 'london', 'sized', 'city', 'virus', 'began'],
#  ['china', 'coronavirus', 'lessons', 'learned', 'sars', 'outbreak'],
#  ['british', 'citizens', 'trying', 'flee', 'china'],
#  ['coronavirus', 'viruses', 'spread'],
#  ['coronavirus', 'spreads', 'countries', 'latest', 'updates'],
#  ['chinese', 'residents', 'quarantine', 'call', 'government', 'action'],
#  ['china', 'coronavirus', 'need', 'know', 'words'],
#  ['coronavirus', 'spread', 'protect'],
#  ['timeline', 'china', 'new', 'coronavirus', 'spread'],
#  ['coronavirus', 'need', 'know', 'symptoms', 'risks'],
#  ['uk', 'confirms', 'first', 'two', 'coronavirus', 'cases'],
#  ['coronavirus', 'pakistan', 'evacuate', 'citizens', 'wuhan'],
#  ['india',
#   'first',
#   'coronavirus',
#   'case',
#   'kerala',
#   'student',
#   'wuhan',
#   'tested',
#   'positive'],
#  ['india',
#   'confirms',
#   'first',
#   'case',
#   'coronavirus',
#   'patient',
#   'kerala',
#   'stable'],
#  ['china',
#   'coronavirus',
#   'death',
#   'toll',
#   'rises',
#   'confirmed',
#   'cases',
#   'soar'],
#  ['facebook',
#   'remove',
#   'coronavirus',
#   'fake',
#   'news',
#   'flags',
#   'global',
#   'emergency'],
#  ['coronavirus',
#   'spurt',
#   'fertiliser',
#   'import',
#   'costs',
#   'seen',
#   'due',
#   'plant',
#   'closure'],
#  ['coronavirus',
#   'air',
#   'india',
#   'plane',
#   'leave',
#   'beijing',
#   'evacuate',
#   'indians'],
#  ['us',
#   'tells',
#   'citizens',
#   'travel',
#   'china',
#   'coronavirus',
#   'spread',
#   'worsens'],
#  ['coronavirus',
#   'china',
#   'toll',
#   'soars',
#   'declares',
#   'world',
#   'health',
#   'emergency'],
#  ['top', 'events', 'day', 'economic', 'survey', 'uk', 'set', 'leave', 'eu'],
#  ['declares',
#   'international',
#   'emergency',
#   'novel',
#   'coronavirus',
#   'outbreak'],
#  ['coronavirus',
#   'little',
#   'impact',
#   'us',
#   'economy',
#   'says',
#   'trump',
#   'adviser'],
#  ['many',
#   'countries',
#   'unprepared',
#   'face',
#   'coronavirus',
#   'global',
#   'health',
#   'monitor'],
#  ['global',
#   'markets',
#   'hit',
#   'hard',
#   'indices',
#   'catch',
#   'wuhan',
#   'flu',
#   'sensex',
#   'falls',
#   'pts'],
#  ['breakthrough',
#   'australia',
#   'researchers',
#   'grow',
#   'coronavirus',
#   'cell',
#   'culture'],
#  ['india',
#   'steps',
#   'preparations',
#   'fight',
#   'potential',
#   'coronavirus',
#   'outbreak'],
#  ['coronavirus',
#   'outbreak',
#   'kept',
#   'observation',
#   'delhi',
#   'rml',
#   'hospital'],
#  ['first',
#   'coronavirus',
#   'case',
#   'confirmed',
#   'germany',
#   'bavarian',
#   'health',
#   'ministry'],
#  ['canada',
#   'first',
#   'presumptive',
#   'coronavirus',
#   'case',
#   'detected',
#   'toronto'],
#  ['coronavirus', 'death', 'toll', 'rises', 'china', 'confirmed', 'cases'],
#  ['scientists',
#   'begin',
#   'work',
#   'vaccine',
#   'tackle',
#   'coronavirus',
#   'outbreak'],
#  ['wuhan',
#   'coronavirus',
#   'outbreak',
#   'hits',
#   'south',
#   'korea',
#   'second',
#   'person',
#   'tests',
#   'positive'],
#  ['ten',
#   'cities',
#   'china',
#   'hubei',
#   'suspend',
#   'public',
#   'transportation',
#   'coronavirus'],
#  ['death', 'toll', 'coronavirus', 'rises', 'china', 'confirmed', 'cases'],
#  ['repeat',
#   'sars',
#   'crisis',
#   'china',
#   'virus',
#   'outbreak',
#   'rattles',
#   'financial',
#   'markets'],
#  ['coronavirus',
#   'outbreak',
#   'toll',
#   'rises',
#   'china',
#   'warns',
#   'virus',
#   'could',
#   'spread'],
#  ['coronavirus', 'spreads', 'china', 'new', 'deadly', 'virus', 'explained'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'us',
#   'raises',
#   'travel',
#   'warning',
#   'singapore',
#   'bans',
#   'chinese',
#   'travelers',
#   'outbreak',
#   'spreads'],
#  ['things', 'know', 'stock', 'market', 'opens', 'friday'],
#  ['stock',
#   'market',
#   'live',
#   'updates',
#   'dow',
#   'amazon',
#   'trillion',
#   'caterpillar',
#   'warning'],
#  ['novacyt', 'shares', 'jump', 'launch', 'coronavirus', 'test'],
#  ['new', 'coronavirus', 'likely', 'push', 'china', 'step', 'stimulus'],
#  ['costa',
#   'cruises',
#   'says',
#   'passenger',
#   'common',
#   'flu',
#   'tourists',
#   'held',
#   'amid',
#   'coronavirus',
#   'fears'],
#  ['trump',
#   'says',
#   'coronavirus',
#   'outbreak',
#   'control',
#   'small',
#   'problem',
#   'us'],
#  ['airlines', 'suspend', 'flights', 'china', 'amid', 'coronavirus', 'fears'],
#  ['goldman',
#   'sachs',
#   'expects',
#   'coronavirus',
#   'outbreak',
#   'weigh',
#   'us',
#   'economic',
#   'growth',
#   'quarter'],
#  ['facebook', 'remove', 'misinformation', 'coronavirus'],
#  ['uk', 'confirms', 'first', 'coronavirus', 'cases'],
#  ['oreo',
#   'maker',
#   'mondelez',
#   'says',
#   'coronavirus',
#   'could',
#   'hurt',
#   'sales',
#   'first',
#   'quarter'],
#  ['state',
#   'department',
#   'lets',
#   'non',
#   'emergency',
#   'employees',
#   'leave',
#   'embassy',
#   'beijing',
#   'coronavirus',
#   'spreads'],
#  ['declares',
#   'china',
#   'coronavirus',
#   'killed',
#   'global',
#   'health',
#   'emergency'],
#  ['watch',
#   'officials',
#   'explain',
#   'global',
#   'threat',
#   'coronavirus',
#   'outbreak'],
#  ['cdc',
#   'confirms',
#   'first',
#   'human',
#   'human',
#   'transmission',
#   'coronavirus',
#   'us'],
#  ['coronavirus',
#   'cases',
#   'top',
#   'surpassing',
#   'sars',
#   'outbreak',
#   'less',
#   'month'],
#  ['ex',
#   'obama',
#   'health',
#   'advisor',
#   'us',
#   'needs',
#   'stop',
#   'panicking',
#   'hysterical',
#   'coronavirus'],
#  ['china',
#   'deadly',
#   'coronavirus',
#   'could',
#   'good',
#   'us',
#   'jobs',
#   'manufacturing',
#   'says',
#   'trump',
#   'commerce',
#   'secretary',
#   'wilbur',
#   'ross'],
#  ['coronavirus',
#   'outbreak',
#   'declared',
#   'global',
#   'health',
#   'emergency',
#   'us',
#   'confirms',
#   'first',
#   'human',
#   'transmission'],
#  ['russia', 'closes', 'border', 'china', 'prevent', 'spread', 'coronavirus'],
#  ['europe',
#   'biggest',
#   'oil',
#   'company',
#   'warns',
#   'tough',
#   'uncertain',
#   'market',
#   'coronavirus',
#   'fears',
#   'intensify'],
#  ['india', 'confirms', 'first', 'coronavirus', 'case'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'china',
#   'says',
#   'death',
#   'toll',
#   'hits',
#   'india',
#   'reports',
#   'first',
#   'case'],
#  ['amazon',
#   'restricts',
#   'employee',
#   'travel',
#   'china',
#   'notice',
#   'coronavirus',
#   'spreads'],
#  ['flight',
#   'carrying',
#   'us',
#   'citizens',
#   'wuhan',
#   'arrives',
#   'california',
#   'cdc',
#   'says'],
#  ['boeing', 'concerned', 'coronavirus', 'impact', 'air', 'travel'],
#  ['ceo',
#   'chemical',
#   'giant',
#   'dow',
#   'coronavirus',
#   'concerns',
#   'increasing',
#   'demand',
#   'cleaning',
#   'products'],
#  ['uk',
#   'confirms',
#   'first',
#   'coronavirus',
#   'cases',
#   'outbreak',
#   'spreads',
#   'globally'],
#  ['wuhan', 'coronavirus', 'cases', 'confirmed', 'worldwide'],
#  ['hong',
#   'kong',
#   'art',
#   'fair',
#   'faces',
#   'calls',
#   'cancel',
#   'amid',
#   'coronavirus',
#   'fears'],
#  ['coronavirus', 'spreads', 'fear', 'fueling', 'racism', 'xenophobia'],
#  ['wuhan', 'streets', 'described', 'eerie', 'see', 'look', 'like'],
#  ['china', 'marks', 'deadliest', 'day', 'outbreak'],
#  ['asian',
#   'markets',
#   'recover',
#   'little',
#   'coronavirus',
#   'fears',
#   'sunk',
#   'stocks'],
#  ['apple', 'stands', 'lose', 'lot', 'coronavirus', 'outbreak'],
#  ['coronavirus',
#   'could',
#   'cost',
#   'china',
#   'economy',
#   'billion',
#   'quarter',
#   'beijing',
#   'act',
#   'fast',
#   'avert',
#   'bigger',
#   'hit'],
#  ['coronavirus', 'could', 'cost', 'china', 'economy', 'billion', 'quarter'],
#  ['pillows', 'hot', 'meals', 'airlines', 'adopt', 'preventative', 'measures'],
#  ['see', 'hospitals', 'built', 'coronavirus', 'patients', 'wuhan'],
#  ['meanwhile', 'another', 'deadly', 'virus', 'infected', 'million', 'us'],
#  ['grapefruit',
#   'day',
#   'keeps',
#   'coronavirus',
#   'away',
#   'desperate',
#   'chinese',
#   'resort',
#   'using',
#   'fruit',
#   'face',
#   'masks'],
#  ['chicago',
#   'man',
#   'first',
#   'us',
#   'person',
#   'person',
#   'china',
#   'coronavirus',
#   'case'],
#  ['coronavirus', 'held', 'italian', 'cruise', 'ship', 'passengers', 'tested'],
#  ['satellite', 'images', 'show', 'deserted', 'roads', 'waterways', 'wuhan'],
#  ['chinese',
#   'hospitals',
#   'start',
#   'use',
#   'ai',
#   'powered',
#   'robots',
#   'treat',
#   'coronavirus',
#   'patients'],
#  ['french', 'asians', 'hit', 'back', 'racism', 'virus', 'hashtag'],
#  ['scientists', 'develop', 'vaccine', 'chinese', 'coronavirus'],
#  ['american',
#   'describes',
#   'like',
#   'wuhan',
#   'deadly',
#   'coronavirus',
#   'continues',
#   'spread'],
#  ['two',
#   'college',
#   'students',
#   'ohio',
#   'tested',
#   'deadly',
#   'coronavirus',
#   'killed',
#   'china'],
#  ['chinese', 'coronavirus', 'face', 'masks', 'dogs', 'hit', 'market'],
#  ['chinese', 'coronavirus', 'doctors', 'beaten', 'relative', 'victim'],
#  ['french',
#   'doctor',
#   'infected',
#   'wuhan',
#   'coronavirus',
#   'country',
#   'first',
#   'human',
#   'human',
#   'spread'],
#  ['coronavirus', 'fears', 'british', 'airways', 'flight', 'hong', 'kong'],
#  ['coronavirus', 'hits', 'uk', 'two', 'english', 'patients', 'diagnosed'],
#  ['wirral',
#   'residents',
#   'react',
#   'news',
#   'britons',
#   'wuhan',
#   'quarantined',
#   'local',
#   'hospital'],
#  ['china', 'accused', 'lying', 'true', 'scale', 'coronavirus'],
#  ['coronavirus', 'may', 'spread', 'touching', 'contaminated', 'surfaces'],
#  ['social',
#   'media',
#   'rumors',
#   'usc',
#   'student',
#   'coronavirus',
#   'triggered',
#   'online',
#   'petition',
#   'cancel',
#   'classes'],
#  ['wuhan', 'coronavirus', 'patients', 'spit', 'doctors', 'spread', 'disease'],
#  ['drones',
#   'repurposed',
#   'spray',
#   'disinfectant',
#   'villages',
#   'cities',
#   'china',
#   'hit',
#   'coronavirus'],
#  ['dettol',
#   'kill',
#   'deadly',
#   'wuhan',
#   'coronavirus',
#   'finally',
#   'reached',
#   'uk'],
#  ['china',
#   'sends',
#   'planes',
#   'bring',
#   'stranded',
#   'overseas',
#   'residents',
#   'back',
#   'home',
#   'wuhan'],
#  ['american', 'man', 'trapped', 'wuhan', 'feels', 'like', 'twilight', 'zone'],
#  ['google',
#   'searches',
#   'corona',
#   'beer',
#   'virus',
#   'spike',
#   'people',
#   'thinking',
#   'linked',
#   'deadly',
#   'coronavirus'],
#  ['coronavirus',
#   'british',
#   'man',
#   'forced',
#   'leave',
#   'wife',
#   'behind',
#   'wuhan'],
#  ['man', 'lies', 'dead', 'streets', 'coronavirus', 'ground', 'zero', 'wuhan'],
#  ['british',
#   'father',
#   'stranded',
#   'wuhan',
#   'chinese',
#   'wife',
#   'baby',
#   'missing',
#   'evacuation',
#   'flight'],
#  ['face',
#   'masks',
#   'sell',
#   'online',
#   'shops',
#   'across',
#   'britain',
#   'coronavirus',
#   'panic'],
#  ['study',
#   'coronavirus',
#   'bats',
#   'sheds',
#   'light',
#   'killer',
#   'virus',
#   'evolves'],
#  ['coronavirus',
#   'reached',
#   'africa',
#   'sudan',
#   'reports',
#   'two',
#   'suspected',
#   'cases'],
#  ['british',
#   'airways',
#   'suspends',
#   'flights',
#   'china',
#   'amid',
#   'coronavirus',
#   'crisis'],
#  ['china',
#   'turned',
#   'us',
#   'offer',
#   'send',
#   'scientists',
#   'fight',
#   'coronavirus'],
#  ['bill',
#   'gates',
#   'predicted',
#   'coronavirus',
#   'like',
#   'outbreak',
#   'netflix',
#   'documentary'],
#  ['chinese',
#   'put',
#   'swastika',
#   'danish',
#   'flag',
#   'pm',
#   'refuses',
#   'apologise',
#   'coronavirus',
#   'china',
#   'flag'],
#  ['hong',
#   'kong',
#   'unions',
#   'threaten',
#   'strikes',
#   'unless',
#   'border',
#   'closed',
#   'stop',
#   'coronavirus'],
#  ['china', 'coronavirus', 'london', 'nyc', 'among', 'cities', 'risk'],
#  ['surgical',
#   'face',
#   'masks',
#   'sell',
#   'us',
#   'pharmacies',
#   'coronavirus',
#   'fears',
#   'death',
#   'toll',
#   'rises'],
#  ['wisconsin', 'father', 'wife', 'young', 'daughters', 'trapped', 'wuhan'],
#  ['birmingham', 'man', 'visited', 'wuhan', 'tested', 'china', 'coronavirus'],
#  ['us', 'airports', 'screen', 'coronavirus'],
#  ['china',
#   'coronavirus',
#   'social',
#   'media',
#   'coded',
#   'criticism',
#   'government'],
#  ['deadly', 'coronavirus', 'outbreak', 'start', 'wuhan', 'animal', 'market'],
#  ['china',
#   'coronavirus',
#   'us',
#   'patients',
#   'tested',
#   'sixth',
#   'possible',
#   'case'],
#  ['johnson',
#   'johnson',
#   'pretty',
#   'confident',
#   'make',
#   'coronavirus',
#   'vaccine'],
#  ['brazen',
#   'airliner',
#   'still',
#   'offering',
#   'flights',
#   'london',
#   'heathrow',
#   'coronavirus',
#   'ravaged',
#   'wuhan'],
#  ['us',
#   'health',
#   'experts',
#   'hosted',
#   'fictional',
#   'coronavirus',
#   'pandemic',
#   'simulation',
#   'three',
#   'months',
#   'ago'],
#  ['china',
#   'use',
#   'status',
#   'major',
#   'superpower',
#   'pressure',
#   'world',
#   'health',
#   'organisation'],
#  ['desperate',
#   'residents',
#   'coronavirus',
#   'hotspot',
#   'wuhan',
#   'describe',
#   'doomsday',
#   'scenes'],
#  ['doctors',
#   'battling',
#   'wuhan',
#   'coronavirus',
#   'outbreak',
#   'wearing',
#   'nappies',
#   'time',
#   'toilet',
#   'breaks'],
#  ['travel', 'safe', 'coronavirus', 'outbreak', 'according', 'expert'],
#  ['fears', 'chinese', 'government', 'secrecy', 'coronavirus', 'facts'],
#  ['early', 'declare', 'china', 'coronavirus', 'international', 'emergency'],
#  ['coronavirus', 'triggers', 'cdc', 'highest', 'travel', 'warning', 'wuhan'],
#  ['chinese', 'coronavirus', 'compared', 'sars', 'common', 'cold'],
#  ['us', 'family', 'chinese', 'city', 'fears', 'coronavirus', 'airborne'],
#  ['possible', 'cases', 'china', 'coronavirus', 'found', 'texas', 'la'],
#  ['china', 'coronavirus', 'vaccine', 'could', 'take', 'years', 'develop'],
#  ['chinese',
#   'students',
#   'coronavirus',
#   'ravaged',
#   'wuhan',
#   'went',
#   'clubbing',
#   'cambridge',
#   'week'],
#  ['deadly', 'chinese', 'coronavirus', 'might', 'already', 'reached', 'uk'],
#  ['chinese',
#   'doctors',
#   'wear',
#   'hazmat',
#   'suits',
#   'treat',
#   'coronavirus',
#   'patients'],
#  ['dow',
#   'jones',
#   'falls',
#   'points',
#   'due',
#   'us',
#   'chinese',
#   'coronavirus',
#   'case'],
#  ['chinese',
#   'woman',
#   'bragged',
#   'cheating',
#   'airport',
#   'coronavirus',
#   'screenings',
#   'tracked',
#   'france'],
#  ['flights', 'wuhan', 'australia', 'screened', 'coronavirus'],
#  ['operation', 'wuhan', 'airlift', 'lands', 'raf', 'brize', 'norton'],
#  ['chinese', 'coronavirus', 'main', 'symptoms', 'dangers'],
#  ['british',
#   'teacher',
#   'lived',
#   'next',
#   'wuhan',
#   'market',
#   'says',
#   'may',
#   'spreading',
#   'disease',
#   'uk'],
#  ['wuhan', 'china', 'coronavirus', 'epicentre', 'sars', 'ebola', 'lab'],
#  ['uk',
#   'doctors',
#   'told',
#   'lock',
#   'suspected',
#   'china',
#   'coronavirus',
#   'patients'],
#  ['us',
#   'testing',
#   'patients',
#   'deadly',
#   'coronavirus',
#   'including',
#   'texas',
#   'university',
#   'student'],
#  ['china', 'coronavirus', 'super', 'spreader', 'health', 'care', 'workers'],
#  ['life', 'support', 'machine', 'saves', 'china', 'coronavirus', 'patient'],
#  ['jfk', 'sf', 'lax', 'airports', 'screen', 'chinese', 'coronavirus'],
#  ['fears', 'chinese', 'patients', 'new', 'wuhan', 'coronavirus'],
#  ['suspected',
#   'coronavirus',
#   'patient',
#   'wheeled',
#   'chinese',
#   'airport',
#   'see',
#   'quarantine',
#   'box'],
#  ['coronavirus', 'latest', 'coronavirus', 'struggle', 'survive'],
#  ['coronavirus',
#   'infections',
#   'increase',
#   'flight',
#   'carrying',
#   'passengers',
#   'china',
#   'set',
#   'arrive',
#   'uk'],
#  ['us', 'hospitals', 'preparing', 'coronavirus'],
#  ['state',
#   'department',
#   'citing',
#   'coronavirus',
#   'outbreak',
#   'raises',
#   'china',
#   'travel',
#   'advisory',
#   'travel'],
#  ['coronavirus', 'transmitted'],
#  ['coronavirus', 'outbreak', 'start'],
#  ['coronavirus',
#   'evacuee',
#   'quarantined',
#   'arriving',
#   'california',
#   'health',
#   'department',
#   'says'],
#  ['russia', 'closes', 'border', 'china', 'coronavirus', 'spreads', 'reports'],
#  ['coronavirus',
#   'satellite',
#   'images',
#   'show',
#   'construction',
#   'wuhan',
#   'hospitals'],
#  ['world',
#   'health',
#   'organization',
#   'declares',
#   'coronavirus',
#   'outbreak',
#   'global',
#   'health',
#   'emergency'],
#  ['china', 'building', 'coronavirus', 'hospital', 'week'],
#  ['person',
#   'person',
#   'transmission',
#   'coronavirus',
#   'reported',
#   'us',
#   'cdc',
#   'says'],
#  ['coronavirus',
#   'fears',
#   'sees',
#   'taxi',
#   'driver',
#   'hazmat',
#   'suit',
#   'goggles',
#   'pick',
#   'passenger'],
#  ['thousands',
#   'costa',
#   'cruise',
#   'passengers',
#   'allowed',
#   'disembark',
#   'following',
#   'coronavirus',
#   'scare'],
#  ['asian',
#   'students',
#   'asu',
#   'say',
#   'coronavirus',
#   'case',
#   'school',
#   'made',
#   'students',
#   'treat',
#   'differently'],
#  ['coronavirus', 'death', 'toll', 'increases', 'latest', 'update', 'cases'],
#  ['us',
#   'offering',
#   'additional',
#   'evacuation',
#   'flights',
#   'china',
#   'coronavirus',
#   'fears'],
#  ['coronavirus', 'compare', 'sars', 'mers', 'outbreaks'],
#  ['cases',
#   'coronavirus',
#   'confirmed',
#   'us',
#   'risk',
#   'spreading',
#   'remains',
#   'low',
#   'cdc',
#   'says'],
#  ['coronavirus', 'spreads', 'beijing', 'suburbs', 'close'],
#  ['coronavirus',
#   'case',
#   'asu',
#   'prompts',
#   'petition',
#   'university',
#   'cancel',
#   'classes'],
#  ['declares', 'global', 'health', 'emergency', 'coronavirus', 'cases', 'top'],
#  ['coronavirus',
#   'deaths',
#   'top',
#   'cdc',
#   'extends',
#   'travel',
#   'advisory',
#   'china'],
#  ['misinformation', 'coronavirus', 'spreading', 'online'],
#  ['nearly', 'china', 'infected', 'coronavirus', 'dead'],
#  ['china', 'reports', 'coronavirus', 'cases', 'death', 'toll'],
#  ['china',
#   'building',
#   'hospital',
#   'treat',
#   'virus',
#   'expands',
#   'lockdowns',
#   'cities'],
#  ['says', 'china', 'coronavirus', 'global', 'health', 'emergency'],
#  ['china', 'locks', 'cities', 'epicenter', 'coronavirus', 'outbreak'],
#  ['china',
#   'halts',
#   'transportation',
#   'wuhan',
#   'stop',
#   'spread',
#   'coronavirus'],
#  ['china',
#   'reports',
#   'new',
#   'cases',
#   'deadly',
#   'sars',
#   'like',
#   'virus',
#   'ahead',
#   'lunar',
#   'new',
#   'year',
#   'holiday'],
#  ['declares', 'global', 'health', 'emergency'],
#  ['u',
#   'reports',
#   'first',
#   'case',
#   'coronavirus',
#   'spread',
#   'person',
#   'person'],
#  ['coronavirus', 'continues', 'spread', 'number', 'cases', 'tops'],
#  ['trump',
#   'administration',
#   'expands',
#   'coronavirus',
#   'screenings',
#   'airports'],
#  ['face', 'masks', 'really', 'protect', 'getting', 'sick'],
#  ['new', 'coronavirus', 'cases', 'confirmed', 'u', 'bringing', 'total'],
#  ['cdc', 'confirms', 'second', 'case', 'coronavirus', 'u'],
#  ['texas',
#   'student',
#   'traveled',
#   'china',
#   'tested',
#   'possible',
#   'coronavirus'],
#  ['china',
#   'confirms',
#   'st',
#   'coronavirus',
#   'death',
#   'outside',
#   'outbreak',
#   'epicenter'],
#  ['coronavirus', 'outbreak', 'gujarat', 'informs', 'mea', 'students', 'china'],
#  ['google', 'joins', 'hands', 'contain', 'coronavirus', 'outbreak'],
#  ['coronavirus', 'cases', 'may', 'undercounted', 'even', 'surge'],
#  ['coronavirus', 'itbp', 'creates', 'bedded', 'facility', 'south', 'delhi'],
#  ['coronavirus', 'discriminate', 'neither'],
#  ['coronavirus',
#   'death',
#   'toll',
#   'likely',
#   'someone',
#   'die',
#   'wuhan',
#   'virus'],
#  ['man',
#   'lies',
#   'dead',
#   'street',
#   'crisis',
#   'hit',
#   'coronavirus',
#   'city',
#   'wuhan'],
#  ['facebook',
#   'bans',
#   'coronavirus',
#   'fake',
#   'news',
#   'false',
#   'cures',
#   'conspiracy',
#   'theories'],
#  ['fridges', 'tvs', 'moved', 'flats', 'brits', 'quarantined', 'coronavirus'],
#  ['happens',
#   'uk',
#   'coronavirus',
#   'patients',
#   'deadly',
#   'disease',
#   'confirmed'],
#  ['symptoms', 'coronavirus', 'protect', 'getting', 'sick'],
#  ['latest',
#   'pictures',
#   'reveal',
#   'rapid',
#   'progress',
#   'hospital',
#   'built',
#   'treat',
#   'coronavirus'],
#  ['coronavirus', 'uk', 'many', 'people'],
#  ['coronavirus',
#   'arrives',
#   'uk',
#   'two',
#   'people',
#   'test',
#   'positive',
#   'deadly',
#   'disease'],
#  ['dog',
#   'owners',
#   'buying',
#   'face',
#   'masks',
#   'protect',
#   'pets',
#   'deadly',
#   'coronavirus'],
#  ['italy',
#   'confirms',
#   'first',
#   'two',
#   'cases',
#   'coronavirus',
#   'passengers',
#   'allowed',
#   'cruise'],
#  ['sanitary',
#   'towels',
#   'fruit',
#   'bottles',
#   'used',
#   'masks',
#   'desperate',
#   'bid',
#   'avoid',
#   'coronavirus'],
#  ['coronavirus',
#   'declared',
#   'global',
#   'emergency',
#   'world',
#   'health',
#   'organisation'],
#  ['uk', 'raises', 'coronavirus', 'threat', 'level', 'death', 'toll', 'rises'],
#  ['first',
#   'person',
#   'person',
#   'transmitted',
#   'case',
#   'coronavirus',
#   'confirmed',
#   'us'],
#  ['man',
#   'died',
#   'chinatown',
#   'people',
#   'refused',
#   'give',
#   'cpr',
#   'coronavirus',
#   'fears'],
#  ['harrowing',
#   'footage',
#   'shows',
#   'dog',
#   'yelping',
#   'barbecued',
#   'alive',
#   'street',
#   'market'],
#  ['flight',
#   'bringing',
#   'brits',
#   'back',
#   'coronavirus',
#   'city',
#   'china',
#   'leave',
#   'tonight'],
#  ['travel',
#   'insurance',
#   'cover',
#   'trip',
#   'china',
#   'affected',
#   'coronavirus',
#   'outbreak'],
#  ['passengers',
#   'trapped',
#   'cruise',
#   'ship',
#   'two',
#   'tested',
#   'deadly',
#   'coronavirus'],
#  ['british',
#   'dad',
#   'may',
#   'forced',
#   'leave',
#   'newborn',
#   'son',
#   'coronavirus',
#   'ground',
#   'zero'],
#  ['people',
#   'searching',
#   'corona',
#   'beer',
#   'virus',
#   'confusing',
#   'lager',
#   'coronavirus'],
#  ['coronavirus',
#   'fears',
#   'grow',
#   'human',
#   'human',
#   'infections',
#   'outside',
#   'china'],
#  ['china', 'richest', 'man', 'donates', 'help', 'tackle', 'coronavirus'],
#  ['coronavirus',
#   'death',
#   'toll',
#   'rises',
#   'first',
#   'case',
#   'reported',
#   'finland'],
#  ['british',
#   'wuhan',
#   'evacuees',
#   'arrive',
#   'back',
#   'uk',
#   'first',
#   'coronavirus',
#   'case',
#   'confirmed'],
#  ['china',
#   'open',
#   'postponed',
#   'due',
#   'coronavirus',
#   'huge',
#   'impact',
#   'world',
#   'championship',
#   'seeding',
#   'qualification'],
#  ['chun',
#   'li',
#   'cosplayer',
#   'swaps',
#   'bodybuilding',
#   'conventions',
#   'treating',
#   'coronavirus',
#   'patients'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'death',
#   'toll',
#   'hits',
#   'number',
#   'infected',
#   'reaches',
#   'globally'],
#  ['plane', 'carrying', 'britons', 'others', 'china', 'wuhan', 'lands', 'uk'],
#  ['armenia',
#   'suspends',
#   'visa',
#   'free',
#   'travel',
#   'chinese',
#   'citizens',
#   'virus',
#   'fears',
#   'deputy',
#   'pm'],
#  ['travellers',
#   'beat',
#   'china',
#   'virus',
#   'lockdown',
#   'via',
#   'bridge',
#   'yangtze'],
#  ['etihad',
#   'suspends',
#   'flights',
#   'beijing',
#   'japan',
#   'nagoya',
#   'low',
#   'demand'],
#  ['russia',
#   'consumer',
#   'safety',
#   'watchdog',
#   'reporting',
#   'two',
#   'cases',
#   'says',
#   'virus',
#   'spread'],
#  ['u',
#   'others',
#   'tighten',
#   'curbs',
#   'travel',
#   'china',
#   'virus',
#   'toll',
#   'hits'],
#  ['factbox', 'latest', 'coronavirus', 'spreading', 'china', 'beyond'],
#  ['plane', 'carrying', 'britons', 'others', 'china', 'wuhan', 'lands', 'uk'],
#  ['german',
#   'coronavirus',
#   'cases',
#   'climb',
#   'six',
#   'child',
#   'infected',
#   'ministry'],
#  ['germany', 'expects', 'coronavirus', 'vaccine', 'within', 'months'],
#  ['russia',
#   'consumer',
#   'safety',
#   'watchdog',
#   'reporting',
#   'two',
#   'cases',
#   'says',
#   'virus',
#   'spread'],
#  ['russia', 'reports', 'first', 'two', 'cases', 'coronavirus', 'deputy', 'pm'],
#  ['france',
#   'pasteur',
#   'institute',
#   'foundation',
#   'hoping',
#   'develop',
#   'coronavirus',
#   'vaccine'],
#  ['south', 'korean', 'evacuees', 'wuhan', 'welcomed', 'quarantine', 'centers'],
#  ['factbox',
#   'russia',
#   'reports',
#   'first',
#   'two',
#   'cases',
#   'coronavirus',
#   'deputy',
#   'pm'],
#  ['factbox',
#   'companies',
#   'feel',
#   'impact',
#   'coronavirus',
#   'outbreak',
#   'china'],
#  ['coronavirus', 'spreads', 'spurious', 'online', 'claims', 'hong', 'kong'],
#  ['russia',
#   'reports',
#   'first',
#   'two',
#   'coronavirus',
#   'cases',
#   'evacuate',
#   'citizens',
#   'china'],
#  ['coronavirus',
#   'top',
#   'hong',
#   'kong',
#   'medical',
#   'school',
#   'flouts',
#   'health',
#   'guidelines',
#   'lets',
#   'staff',
#   'working',
#   'mainland',
#   'skip',
#   'quarantine'],
#  ['coronavirus',
#   'lawmaker',
#   'local',
#   'factory',
#   'team',
#   'reusable',
#   'antibacterial',
#   'masks',
#   'though',
#   'efficacy',
#   'viruses',
#   'unknown'],
#  ['coronavirus',
#   'italy',
#   'declares',
#   'state',
#   'emergency',
#   'two',
#   'cases',
#   'confirmed'],
#  ['coronavirus',
#   'number',
#   'cases',
#   'hong',
#   'kong',
#   'could',
#   'jump',
#   'almost',
#   'per',
#   'cent',
#   'next',
#   'two',
#   'weeks',
#   'scientist',
#   'predicts'],
#  ['paper',
#   'human',
#   'transmission',
#   'coronavirus',
#   'sets',
#   'social',
#   'media',
#   'storm',
#   'china'],
#  ['coronavirus',
#   'thousands',
#   'public',
#   'hospital',
#   'staff',
#   'vote',
#   'strike',
#   'action',
#   'saturday',
#   'ahead',
#   'potential',
#   'walkout',
#   'next',
#   'week'],
#  ['china',
#   'unemployment',
#   'risks',
#   'surge',
#   'service',
#   'providers',
#   'bear',
#   'brunt',
#   'coronavirus',
#   'outbreak'],
#  ['singapore',
#   'closes',
#   'borders',
#   'chinese',
#   'travellers',
#   'stem',
#   'spread',
#   'coronavirus'],
#  ['coronavirus',
#   'hong',
#   'kong',
#   'restaurant',
#   'group',
#   'calls',
#   'border',
#   'closure',
#   'says',
#   'virus',
#   'fears',
#   'hurting',
#   'business',
#   'protests'],
#  ['chinese',
#   'stranded',
#   'overseas',
#   'set',
#   'arrive',
#   'home',
#   'friday',
#   'night',
#   'beijing',
#   'says'],
#  ['two', 'people', 'uk', 'test', 'positive', 'coronavirus'],
#  ['hong',
#   'kong',
#   'leader',
#   'carrie',
#   'lam',
#   'urges',
#   'local',
#   'residents',
#   'travel',
#   'mainland',
#   'china',
#   'complete',
#   'border',
#   'shutdown',
#   'yet'],
#  ['coronavirus',
#   'visitor',
#   'arrivals',
#   'mainland',
#   'drop',
#   'nearly',
#   'per',
#   'cent',
#   'hong',
#   'kong',
#   'government',
#   'closes',
#   'border',
#   'crossings'],
#  ['double',
#   'whammy',
#   'coronavirus',
#   'protests',
#   'send',
#   'hong',
#   'kong',
#   'home',
#   'prices',
#   'plunging',
#   'say',
#   'property',
#   'analysts'],
#  ['coronavirus',
#   'hongkongers',
#   'online',
#   'orders',
#   'masks',
#   'cancelled',
#   'overseas',
#   'suppliers',
#   'report',
#   'shortages'],
#  ['coronavirus',
#   'hong',
#   'kong',
#   'banks',
#   'close',
#   'per',
#   'cent',
#   'branches',
#   'public',
#   'safety',
#   'measure',
#   'amid',
#   'outbreak'],
#  ['coronavirus',
#   'global',
#   'travel',
#   'restrictions',
#   'imposed',
#   'chinese',
#   'travellers',
#   'airlines',
#   'cut',
#   'flights',
#   'mainland'],
#  ['india', 'homeopathic', 'cure', 'coronavirus', 'immature', 'irresponsible'],
#  ['hong',
#   'kong',
#   'airlines',
#   'cut',
#   'hundreds',
#   'jobs',
#   'finances',
#   'worsen',
#   'amid',
#   'coronavirus',
#   'outbreak'],
#  ['coronavirus',
#   'doctors',
#   'health',
#   'care',
#   'workers',
#   'hong',
#   'kong',
#   'join',
#   'calls',
#   'border',
#   'closure',
#   'mainland',
#   'china',
#   'threatening',
#   'strikes',
#   'strongly',
#   'worded',
#   'letters',
#   'officials'],
#  ['china',
#   'coronavirus',
#   'pressure',
#   'builds',
#   'hong',
#   'kong',
#   'hotels',
#   'turn',
#   'away',
#   'guests',
#   'mainland'],
#  ['hong', 'kong', 'confirms', 'th', 'case', 'deadly', 'coronavirus'],
#  ['china', 'coronavirus', 'singapore', 'seven', 'habits', 'good', 'hygiene'],
#  ['china',
#   'coronavirus',
#   'tens',
#   'millions',
#   'masks',
#   'way',
#   'hong',
#   'kong',
#   'prisoners',
#   'work',
#   'around',
#   'clock',
#   'make',
#   'city',
#   'confirms',
#   'th',
#   'case'],
#  ['japan',
#   'bans',
#   'coronavirus',
#   'infected',
#   'travellers',
#   'outcry',
#   'lax',
#   'response'],
#  ['china',
#   'goes',
#   'global',
#   'search',
#   'protective',
#   'suits',
#   'masks',
#   'goggles',
#   'coronavirus',
#   'infections',
#   'begin',
#   'take'],
#  ['coronavirus',
#   'south',
#   'korea',
#   'thailand',
#   'confirm',
#   'cases',
#   'human',
#   'transmission'],
#  ['china',
#   'coronavirus',
#   'find',
#   'surgical',
#   'masks',
#   'hong',
#   'kong',
#   'throw',
#   'used',
#   'ones',
#   'away',
#   'myths',
#   'surrounding'],
#  ['china',
#   'coronavirus',
#   'hubei',
#   'residents',
#   'found',
#   'hong',
#   'kong',
#   'hotels',
#   'security',
#   'chiefs',
#   'say',
#   'powerless',
#   'isolate',
#   'deport'],
#  ['china',
#   'coronavirus',
#   'tensions',
#   'high',
#   'thousands',
#   'queue',
#   'hong',
#   'kong',
#   'desperate',
#   'masks',
#   'many',
#   'leaving',
#   'empty',
#   'handed'],
#  ['coronavirus',
#   'levi',
#   'shuts',
#   'half',
#   'mainland',
#   'china',
#   'stores',
#   'expects',
#   'dent',
#   'earnings'],
#  ['coronavirus',
#   'hongkongers',
#   'whose',
#   'livelihoods',
#   'depend',
#   'able',
#   'cross',
#   'border'],
#  ['china',
#   'coronavirus',
#   'study',
#   'places',
#   'incubation',
#   'period',
#   'around',
#   'days'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'nurses',
#   'call',
#   'sick',
#   'protest',
#   'government',
#   'refusal',
#   'close',
#   'borders'],
#  ['china',
#   'coronavirus',
#   'quarantine',
#   'anyone',
#   'coming',
#   'hong',
#   'kong',
#   'epicentre',
#   'deadly',
#   'outbreak',
#   'immediately',
#   'medical',
#   'experts',
#   'say'],
#  ['long',
#   'queues',
#   'outlets',
#   'across',
#   'hong',
#   'kong',
#   'selling',
#   'masks',
#   'panic',
#   'buying',
#   'continues',
#   'amid',
#   'wuhan',
#   'coronavirus',
#   'outbreak'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'mainland',
#   'passengers',
#   'descend',
#   'west',
#   'kowloon',
#   'station',
#   'ahead',
#   'widespread',
#   'suspensions',
#   'cross',
#   'border',
#   'travel'],
#  ['coronavirus', 'crisis', 'exposing', 'ills', 'china', 'model'],
#  ['coronavirus',
#   'rubbing',
#   'salt',
#   'wounds',
#   'hong',
#   'kong',
#   'tourism',
#   'industry',
#   'caused',
#   'anti',
#   'government',
#   'protests'],
#  ['coronavirus',
#   'chinese',
#   'health',
#   'experts',
#   'warn',
#   'patients',
#   'get',
#   'reinfected'],
#  ['coronavirus',
#   'us',
#   'citizen',
#   'evacuated',
#   'wuhan',
#   'quarantined',
#   'trying',
#   'flee',
#   'base'],
#  ['two',
#   'hongkongers',
#   'infected',
#   'mainland',
#   'china',
#   'city',
#   'gets',
#   'th',
#   'confirmed',
#   'coronavirus',
#   'case'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'professor',
#   'yuen',
#   'kwok',
#   'yung',
#   'says',
#   'effectiveness',
#   'drugs',
#   'could',
#   'judged',
#   'within',
#   'weeks',
#   'tests',
#   'due',
#   'start',
#   'city'],
#  ['hong',
#   'kong',
#   'protesters',
#   'disrupt',
#   'mtr',
#   'services',
#   'declare',
#   'dawn',
#   'anti',
#   'epidemic',
#   'strikes',
#   'government',
#   'handling',
#   'wuhan',
#   'coronavirus',
#   'outbreak'],
#  ['coronavirus',
#   'global',
#   'health',
#   'emergency',
#   'declared',
#   'world',
#   'health',
#   'organisation',
#   'reversing',
#   'earlier',
#   'decision',
#   'outbreak'],
#  ['hong',
#   'kong',
#   'unemployment',
#   'rate',
#   'expected',
#   'hit',
#   'levels',
#   'per',
#   'cent',
#   'sars',
#   'wuhan',
#   'coronavirus',
#   'deals',
#   'new',
#   'blow',
#   'protest',
#   'hit',
#   'economy',
#   'tourism'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'researchers',
#   'already',
#   'developed',
#   'vaccine',
#   'need',
#   'time',
#   'test',
#   'expert',
#   'reveals'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'scrambles',
#   'roll',
#   'containment',
#   'plan',
#   'stopping',
#   'short',
#   'total',
#   'closure',
#   'cuts',
#   'cross',
#   'border',
#   'travel',
#   'reduced',
#   'transport',
#   'services',
#   'mainland'],
#  ['china',
#   'coronavirus',
#   'flights',
#   'week',
#   'hong',
#   'kong',
#   'mainland',
#   'cut',
#   'new',
#   'measures',
#   'fight',
#   'outbreak'],
#  ['dentist',
#   'donor',
#   'dude',
#   'van',
#   'canadian',
#   'coronavirus',
#   'profiteers',
#   'run',
#   'rampant',
#   'vancouver',
#   'donates',
#   'thousands',
#   'n',
#   'medical',
#   'masks',
#   'wuhan'],
#  ['china',
#   'coronavirus',
#   'african',
#   'nations',
#   'quarantine',
#   'symptomatic',
#   'passengers',
#   'china',
#   'cases',
#   'confirmed'],
#  ['china',
#   'coronavirus',
#   'us',
#   'reports',
#   'first',
#   'case',
#   'person',
#   'person',
#   'transmission',
#   'france',
#   'announces',
#   'sixth',
#   'confirmed',
#   'infection'],
#  ['wilbur',
#   'ross',
#   'says',
#   'coronavirus',
#   'could',
#   'bring',
#   'jobs',
#   'back',
#   'us',
#   'china'],
#  ['public',
#   'warned',
#   'online',
#   'scams',
#   'dubious',
#   'products',
#   'amid',
#   'hong',
#   'kong',
#   'mask',
#   'buying',
#   'frenzy',
#   'coronavirus',
#   'fears',
#   'continue'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'pro',
#   'establishment',
#   'party',
#   'dab',
#   'backs',
#   'proposal',
#   'temporarily',
#   'close',
#   'border',
#   'checkpoints',
#   'mainland',
#   'china',
#   'control',
#   'outbreak'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'workers',
#   'told',
#   'stay',
#   'home',
#   'government',
#   'businesses',
#   'try',
#   'stop',
#   'virus',
#   'spreading'],
#  ['hong',
#   'kong',
#   'medical',
#   'workers',
#   'draw',
#   'fortune',
#   'sticks',
#   'decide',
#   'works',
#   'coronavirus',
#   'quarantine',
#   'wards'],
#  ['china',
#   'coronavirus',
#   'fear',
#   'infection',
#   'lack',
#   'consultation',
#   'drive',
#   'defiance',
#   'hong',
#   'kong',
#   'quarantine',
#   'plan'],
#  ['checks',
#   'lacking',
#   'hong',
#   'kong',
#   'borders',
#   'officials',
#   'work',
#   'wuhan',
#   'coronavirus',
#   'response'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'medical',
#   'experts',
#   'call',
#   'draconian',
#   'measures',
#   'city',
#   'research',
#   'estimates',
#   'already',
#   'cases',
#   'wuhan'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'health',
#   'minister',
#   'admits',
#   'hubei',
#   'entry',
#   'ban',
#   'per',
#   'cent',
#   'effective',
#   'ahead',
#   'meeting',
#   'discuss',
#   'new',
#   'measures',
#   'contagion'],
#  ['china',
#   'coronavirus',
#   'demand',
#   'face',
#   'masks',
#   'surges',
#   'amid',
#   'short',
#   'supply',
#   'hong',
#   'kong',
#   'government',
#   'denies',
#   'accusation',
#   'stockpiled',
#   'safety',
#   'gear',
#   'internal',
#   'use'],
#  ['china',
#   'coronavirus',
#   'calls',
#   'close',
#   'hong',
#   'kong',
#   'border',
#   'split',
#   'medical',
#   'sector'],
#  ['china',
#   'coronavirus',
#   'baby',
#   'fever',
#   'put',
#   'hong',
#   'kong',
#   'isolation',
#   'ward',
#   'precaution',
#   'father',
#   'failed',
#   'reveal',
#   'works',
#   'mainland',
#   'hospital'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'police',
#   'protesters',
#   'clash',
#   'fanling',
#   'anger',
#   'erupts',
#   'proposal',
#   'use',
#   'housing',
#   'block',
#   'quarantine',
#   'site'],
#  ['china',
#   'coronavirus',
#   'hong',
#   'kong',
#   'ban',
#   'anyone',
#   'hubei',
#   'province',
#   'entering',
#   'city',
#   'response',
#   'mounting',
#   'calls',
#   'tighten',
#   'border',
#   'checks'],
#  ['china',
#   'coronavirus',
#   'forces',
#   'andy',
#   'lau',
#   'call',
#   'hong',
#   'kong',
#   'concerts',
#   'following',
#   'closures',
#   'disneyland',
#   'ocean',
#   'park',
#   'notice'],
#  ['influencers', 'tell', 'tiktok', 'stop', 'purging', 'videos'],
#  ['outbreaks', 'xenophobia', 'west', 'coronavirus', 'spreads'],
#  ['help',
#   'hindrance',
#   'chinese',
#   'politics',
#   'affected',
#   'coronavirus',
#   'response'],
#  ['coronavirus', 'worried'],
#  ['man',
#   'lies',
#   'dead',
#   'street',
#   'image',
#   'captures',
#   'wuhan',
#   'coronavirus',
#   'crisis'],
#  ['city', 'suffocating', 'diary', 'wuhan', 'coronavirus', 'lockdown'],
#  ['protect', 'coronavirus'],
#  ['race', 'contain', 'coronavirus', 'podcast'],
#  ['coronavirus',
#   'outbreak',
#   'britons',
#   'fly',
#   'wuhan',
#   'death',
#   'toll',
#   'passes'],
#  ['bat',
#   'soup',
#   'dodgy',
#   'cures',
#   'diseasology',
#   'spread',
#   'coronavirus',
#   'misinformation'],
#  ['poorer',
#   'countries',
#   'suffer',
#   'global',
#   'health',
#   'crises',
#   'need',
#   'help',
#   'handle',
#   'coronavirus',
#   'dr',
#   'claude',
#   'posala'],
#  ['tell', 'us', 'affected', 'coronavirus'],
#  ['hongkongers', 'take', 'chances', 'deadly', 'coronavirus', 'pictures'],
#  ['timelapse',
#   'footage',
#   'captures',
#   'wuhan',
#   'hospital',
#   'construction',
#   'video'],
#  ['coronavirus',
#   'british',
#   'family',
#   'heads',
#   'exit',
#   'flight',
#   'chinese',
#   'wife',
#   'allowed',
#   'board',
#   'video'],
#  ['declares', 'coronavirus', 'global', 'health', 'emergency', 'video'],
#  ['british',
#   'resident',
#   'wuhan',
#   'government',
#   'let',
#   'wife',
#   'leave',
#   'video'],
#  ['cruise',
#   'ship',
#   'passengers',
#   'lockdown',
#   'italy',
#   'coronavirus',
#   'fears',
#   'video'],
#  ['wuhan', 'coronavirus', 'grown', 'scientists', 'melbourne', 'video'],
#  ['virus', 'death', 'toll', 'reaches', 'china', 'happened'],
#  ['declares', 'coronavirus', 'global', 'health', 'emergency'],
#  ['coronavirus', 'public', 'health', 'emergencies', 'declared'],
#  ['protect', 'coronavirus', 'infection'],
#  ['wuhan', 'coronavirus', 'know', 'know', 'science', 'weekly', 'podcast'],
#  ['guardian',
#   'view',
#   'china',
#   'coronavirus',
#   'scrutiny',
#   'stigma',
#   'editorial'],
#  ['coronavirus',
#   'millennials',
#   'housing',
#   'u',
#   'mexico',
#   'border',
#   'wednesday',
#   'news'],
#  ['coronavirus', 'students', 'china', 'colleges', 'many', 'scares'],
#  ['trump',
#   'iowa',
#   'rally',
#   'coronavirus',
#   'spitzer',
#   'telescope',
#   'things',
#   'know',
#   'thursday'],
#  ['coronavirus', 'scares', 'us', 'new', 'unknown', 'vaccine', 'yet'],
#  ['coronavirus',
#   'outbreak',
#   'leads',
#   'cancellation',
#   'blue',
#   'bay',
#   'lpga',
#   'china'],
#  ['coronavirus',
#   'post',
#   'removed',
#   'joanna',
#   'jedrzejczyk',
#   'apologizes',
#   'zhang',
#   'weili'],
#  ['coronavirus',
#   'china',
#   'outbreak',
#   'could',
#   'affect',
#   'back',
#   'school',
#   'shopping'],
#  ['coronavirus', 'pilot', 'addresses', 'questions', 'flying', 'right'],
#  ['n', 'burger', 'sb', 'kobe', 'pilot', 'coronavirus', 'thursday', 'news'],
#  ['thursday',
#   'daily',
#   'briefing',
#   'trump',
#   'iowa',
#   'rally',
#   'coronavirus',
#   'outbreak'],
#  ['coronavirus',
#   'outbreak',
#   'state',
#   'dept',
#   'says',
#   'fly',
#   'americans',
#   'back'],
#  ['americans',
#   'stranded',
#   'wuhan',
#   'china',
#   'coronavirus',
#   'city',
#   'lockdown'],
#  ['coronavirus', 'global', 'health', 'emergency', 'amazon', 'rival', 'news'],
#  ['coronavirus', 'officially', 'global', 'emergency'],
#  ['coronavirus', 'infecting', 'people', 'traveled', 'china'],
#  ['coronavirus', 'threat', 'global', 'drug', 'supply'],
#  ['ai', 'epidemiologist', 'sent', 'first', 'warnings', 'wuhan', 'virus'],
#  ['scientists',
#   'predict',
#   'wuhan',
#   'virus',
#   'outbreak',
#   'get',
#   'much',
#   'worse'],
#  ['wuhan', 'virus', 'snake', 'flu'],
#  ['deescalate', 'war', 'coronavirus'],
#  ['wuhan',
#   'coronavirus',
#   'killed',
#   'people',
#   'countries',
#   'warning',
#   'travel',
#   'china'],
#  ['emergency',
#   'uk',
#   'flight',
#   'wuhan',
#   'canceled',
#   'leaving',
#   'britons',
#   'families',
#   'stranded',
#   'quarantine'],
#  ['tom',
#   'cotton',
#   'claims',
#   'coronavirus',
#   'epidemic',
#   'much',
#   'worse',
#   'china',
#   'admits'],
#  ['us',
#   'passenger',
#   'wuhan',
#   'attempted',
#   'leave',
#   'california',
#   'military',
#   'base',
#   'put',
#   'quarantine'],
#  ['costco',
#   'sample',
#   'stand',
#   'worker',
#   'turned',
#   'away',
#   'kid',
#   'wearing',
#   'face',
#   'mask',
#   'thought',
#   'china',
#   'could',
#   'give',
#   'coronavirus'],
#  ['apocalypse',
#   'american',
#   'student',
#   'trapped',
#   'coronavirus',
#   'hit',
#   'chinese',
#   'city'],
#  ['thousands', 'virus', 'lockdown', 'china', 'backed', 'plant', 'indonesia'],
#  ['people',
#   'trapped',
#   'cruise',
#   'ship',
#   'italy',
#   'woman',
#   'suspected',
#   'coronavirus'],
#  ['american',
#   'airlines',
#   'pilots',
#   'union',
#   'sues',
#   'stop',
#   'carrier',
#   'u',
#   'china',
#   'service'],
#  ['china',
#   'says',
#   'coronavirus',
#   'death',
#   'toll',
#   'hits',
#   'britain',
#   'russia',
#   'report',
#   'first',
#   'cases'],
#  ['coronavirus', 'could', 'cost', 'china', 'economy', 'billion'],
#  ['pillows',
#   'hot',
#   'meals',
#   'airlines',
#   'adopt',
#   'preventative',
#   'measures',
#   'coronavirus'],
#  ['facebook',
#   'google',
#   'twitter',
#   'crack',
#   'fake',
#   'coronavirus',
#   'cures',
#   'misinformation'],
#  ['kenyan',
#   'airways',
#   'suspends',
#   'flights',
#   'china',
#   'amid',
#   'coronavirus',
#   'outbreak'],
#  ['travel',
#   'insurance',
#   'cover',
#   'flights',
#   'canceled',
#   'due',
#   'coronavirus',
#   'outbreak'],
#  ['chinatown',
#   'ghost',
#   'town',
#   'coronavirus',
#   'struck',
#   'fear',
#   'heart',
#   'london'],
#  ['contagion',
#   'jumps',
#   'back',
#   'film',
#   'charts',
#   'nine',
#   'years',
#   'release',
#   'amid',
#   'coronavirus',
#   'outbreak'],
#  ['russia',
#   'reports',
#   'first',
#   'two',
#   'cases',
#   'china',
#   'coronavirus',
#   'deputy',
#   'pm'],
#  ['britain', 'reports', 'first', 'two', 'cases', 'new', 'coronavirus'],
#  ['pilots',
#   'flight',
#   'attendants',
#   'demand',
#   'flights',
#   'china',
#   'stop',
#   'virus',
#   'fear',
#   'mounts',
#   'worldwide'],
#  ['factbox', 'airlines', 'suspend', 'china', 'flights', 'due', 'coronavirus'],
#  ['one',
#   'case',
#   'coronavirus',
#   'symptoms',
#   'among',
#   'french',
#   'evacuated',
#   'minister'],
#  ['explainer',
#   'rapid',
#   'spread',
#   'china',
#   'coronavirus',
#   'fuels',
#   'global',
#   'alarm'],
#  ['china',
#   'wuhan',
#   'mayor',
#   'says',
#   'containing',
#   'virus',
#   'still',
#   'severe',
#   'complex',
#   'task'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'flight',
#   'carrying',
#   'britons',
#   'wuhan',
#   'lands',
#   'uk'],
#  ['chinese',
#   'planes',
#   'bring',
#   'overseas',
#   'wuhan',
#   'citizens',
#   'back',
#   'virus',
#   'hit',
#   'city'],
#  ['americans', 'leave', 'china', 'many', 'stay', 'us', 'advisory'],
#  ['france',
#   'italy',
#   'drag',
#   'euro',
#   'area',
#   'economy',
#   'worst',
#   'quarter',
#   'since'],
#  ['u',
#   'coronavirus',
#   'evacuee',
#   'china',
#   'placed',
#   'quarantine',
#   'order',
#   'trying',
#   'flee',
#   'base'],
#  ['alibaba',
#   'billionaire',
#   'jack',
#   'china',
#   'richest',
#   'man',
#   'pledged',
#   'million',
#   'fight',
#   'coronavirus'],
#  ['outbreaks',
#   'wuhan',
#   'coronavirus',
#   'sars',
#   'likely',
#   'started',
#   'chinese',
#   'wet',
#   'markets',
#   'photos',
#   'show',
#   'markets',
#   'look',
#   'like'],
#  ['coronavirus', 'influencers', 'thing', 'knew', 'would', 'happen'],
#  ['coronavirus', 'spreads', 'fear', 'fueling', 'racism', 'xenophobia'],
#  ['cnn',
#   'blasted',
#   'condemning',
#   'trump',
#   'coronavirus',
#   'task',
#   'force',
#   'lack',
#   'diversity'],
#  ['india', 'bans', 'export', 'kinds', 'respiratory', 'masks'],
#  ['britain',
#   'reports',
#   'two',
#   'cases',
#   'coronavirus',
#   'evacuation',
#   'flight',
#   'china',
#   'lands'],
#  ['champagne',
#   'discusses',
#   'coronavirus',
#   'response',
#   'evacuation',
#   'china',
#   'counterpart'],
#  ['vietnam', 'airlines', 'suspend', 'flights', 'chinese', 'destinations'],
#  ['india',
#   'bans',
#   'export',
#   'protective',
#   'masks',
#   'clothing',
#   'amid',
#   'coronavirus',
#   'outbreak'],
#  ['mask', 'mask', 'confusion', 'spreads', 'coronavirus', 'protection'],
#  ['residents',
#   'clamour',
#   'surgical',
#   'masks',
#   'coronavirus',
#   'hit',
#   'hong',
#   'kong',
#   'stolen',
#   'warehouse'],
#  ['china',
#   'race',
#   'build',
#   'temporary',
#   'hospitals',
#   'fight',
#   'coronavirus',
#   'little',
#   'late'],
#  ['british',
#   'woman',
#   'offered',
#   'evacuation',
#   'flight',
#   'wuhan',
#   'says',
#   'told',
#   'leave',
#   'year',
#   'old',
#   'son',
#   'behind'],
#  ['andrew',
#   'yang',
#   'says',
#   'supporters',
#   'may',
#   'go',
#   'sanders',
#   'iowa',
#   'caucus'],
#  ['people',
#   'saying',
#   'lysol',
#   'sprays',
#   'clorox',
#   'wipes',
#   'fight',
#   'coronavirus'],
#  ['american',
#   'trapped',
#   'wuhan',
#   'despite',
#   'coronavirus',
#   'evacuate',
#   'without',
#   'wife',
#   'son'],
#  ['pakistan', 'immediate', 'plans', 'evacuate', 'citizens', 'china'],
#  ['dow',
#   'drops',
#   'points',
#   'close',
#   'january',
#   'coronavirus',
#   'keeps',
#   'investors',
#   'edge'],
#  ['cruise',
#   'ships',
#   'screen',
#   'passengers',
#   'change',
#   'routes',
#   'battle',
#   'coronavirus',
#   'threat'],
#  ['know', 'coronavirus', 'cases', 'us'],
#  ['everything', 'travelers', 'need', 'know', 'wuhan', 'coronavirus'],
#  ['india', 'recommends', 'homeopathy', 'coronavirus', 'prevention'],
#  ['coronavirus',
#   'china',
#   'prompts',
#   'unicef',
#   'send',
#   'country',
#   'tons',
#   'masks',
#   'suits'],
#  ['infected',
#   'coming',
#   'wuhan',
#   'evacuees',
#   'share',
#   'journey',
#   'home',
#   'instagram'],
#  ['russia', 'says', 'begin', 'bringing', 'citizens', 'china', 'feb'],
#  ['factbox',
#   'countries',
#   'evacuating',
#   'nationals',
#   'china',
#   'virus',
#   'areas'],
#  ['russia', 'says', 'begin', 'bringing', 'citizens', 'china', 'february'],
#  ['chinese', 'city', 'wuhan', 'says', 'acted', 'sooner', 'contain', 'virus'],
#  ['world',
#   'health',
#   'organisation',
#   'call',
#   'arms',
#   'virus',
#   'needs',
#   'global',
#   'response',
#   'help',
#   'china'],
#  ['coronavirus',
#   'first',
#   'human',
#   'transmission',
#   'thailand',
#   'russia',
#   'uk',
#   'confirm',
#   'cases'],
#  ['trump',
#   'got',
#   'number',
#   'us',
#   'coronavirus',
#   'patients',
#   'wrong',
#   'tweet',
#   'top',
#   'outbreak'],
#  ['england',
#   'first',
#   'two',
#   'coronavirus',
#   'patients',
#   'confirmed',
#   'canada',
#   'evacuates',
#   'diplomatic',
#   'staff',
#   'china',
#   'countries',
#   'place',
#   'immigration',
#   'control',
#   'chinese',
#   'citizens'],
#  ['china',
#   'great',
#   'job',
#   'coronavirus',
#   'says',
#   'pathogens',
#   'specialist',
#   'largest',
#   'us',
#   'public',
#   'health',
#   'care',
#   'system'],
#  ['hysteria',
#   'asian',
#   'students',
#   'arizona',
#   'state',
#   'university',
#   'say',
#   'treated',
#   'differently',
#   'case',
#   'wuhan',
#   'coronavirus',
#   'confirmed'],
#  ['american',
#   'airlines',
#   'pilots',
#   'sue',
#   'halt',
#   'us',
#   'china',
#   'flights',
#   'amid',
#   'coronavirus',
#   'fears'],
#  ['devil', 'coronavirus', 'hit', 'european', 'stocks', 'hard'],
#  ['one',
#   'emergency',
#   'hospitals',
#   'wuhan',
#   'panic',
#   'building',
#   'looking',
#   'close',
#   'completion',
#   'watch',
#   'live',
#   'feed',
#   'construction'],
#  ['kellyanne', 'grilled', 'bolton', 'bombshells', 'rare', 'press', 'briefing'],
#  ['coronavirus', 'china', 'quarantines', 'caused', 'global', 'recession'],
#  ['delta',
#   'suspend',
#   'china',
#   'flights',
#   'starting',
#   'feb',
#   'coronavirus',
#   'outbreak',
#   'spreads'],
#  ['swedish',
#   'health',
#   'authority',
#   'says',
#   'woman',
#   'confirmed',
#   'coronavirus'],
#  ['hong',
#   'kong',
#   'universities',
#   'impose',
#   'forced',
#   'quarantine',
#   'students',
#   'returning',
#   'mainland',
#   'coronavirus',
#   'fears'],
#  ['apocalypse', 'u', 'student', 'trapped', 'coronavirus', 'hit', 'wuhan'],
#  ['coronavirus', 'uk', 'pharmacies', 'see', 'sanitiser', 'sales', 'spike'],
#  ['university',
#   'apologizes',
#   'saying',
#   'xenophobia',
#   'common',
#   'reaction',
#   'coronavirus',
#   'spread'],
#  ['satellite',
#   'photos',
#   'show',
#   'deserted',
#   'streets',
#   'wuhan',
#   'city',
#   'enters',
#   'th',
#   'day',
#   'quarantine'],
#  ['travel',
#   'us',
#   'issued',
#   'extreme',
#   'warning',
#   'going',
#   'china',
#   'coronavirus',
#   'continues',
#   'spread'],
#  ['iran', 'suspends', 'flights', 'china', 'due', 'coronavirus'],
#  ['coronavirus', 'quarantine', 'fought', 'disease', 'ages'],
#  ['lot',
#   'chaos',
#   'state',
#   'department',
#   'says',
#   'fly',
#   'americans',
#   'back',
#   'wuhan',
#   'questions',
#   'remain'],
#  ['wuhan',
#   'coronavirus',
#   'seems',
#   'low',
#   'fatality',
#   'rate',
#   'patients',
#   'make',
#   'full',
#   'recoveries',
#   'experts',
#   'reveal',
#   'causing',
#   'panic',
#   'anyway'],
#  ['mistrust',
#   'hampers',
#   'hong',
#   'kong',
#   'battle',
#   'hold',
#   'back',
#   'china',
#   'virus'],
#  ['coronavirus',
#   'argument',
#   'sparks',
#   'violent',
#   'brawl',
#   'australian',
#   'moms',
#   'police'],
#  ['number',
#   'people',
#   'gotten',
#   'wuhan',
#   'coronavirus',
#   'surpassed',
#   'worldwide',
#   'total',
#   'entire',
#   'sars',
#   'pandemic'],
#  ['factbox', 'know', 'new', 'coronavirus'],
#  ['wuhan', 'coronavirus', 'officially', 'spread', 'every', 'region', 'china'],
#  ['anti', 'china', 'sentiment', 'spreads', 'abroad', 'along', 'coronavirus'],
#  ['delta',
#   'air',
#   'lines',
#   'canceling',
#   'flights',
#   'mainland',
#   'china',
#   'amid',
#   'coronavirus',
#   'outbreak'],
#  ['russia',
#   'reports',
#   'first',
#   'coronavirus',
#   'cases',
#   'restricts',
#   'china',
#   'air',
#   'travel'],
#  ['roller', 'coaster', 'week', 'stocks', 'happened'],
#  ['pasteur', 'institute', 'eyes', 'coronavirus', 'vaccine'],
#  ['coronavirus', 'britons', 'wuhan', 'evacuation', 'flight', 'land', 'uk'],
#  ['china',
#   'covering',
#   'number',
#   'dead',
#   'says',
# ...
#  ['massachusetts',
#   'man',
#   'coronavirus',
#   'state',
#   'health',
#   'officials',
#   'say',
#   'us',
#   'cases',
#   'rise'],
#  ['china',
#   'reports',
#   'outbreak',
#   'deadly',
#   'bird',
#   'flu',
#   'among',
#   'chickens',
#   'hunan',
#   'province',
#   'human',
#   'cases',
#   'yet'],
#  ['coronavirus', 'spreading', 'anti', 'chinese', 'sentiment', 'xenophobia'],
#  ['muscled',
#   'chinese',
#   'cosplayer',
#   'puts',
#   'fantasy',
#   'costumes',
#   'aside',
#   'help',
#   'fight',
#   'coronavirus'],
#  ['eighth', 'us', 'case', 'new', 'coronavirus', 'confirmed', 'massachussetts'],
#  ['major',
#   'us',
#   'airlines',
#   'expand',
#   'flight',
#   'cancellations',
#   'china',
#   'hong',
#   'kong'],
#  ['th', 'us', 'coronavirus', 'case', 'confirmed', 'massachusetts'],
#  ['u', 'confirms', 'th', 'case', 'coronavirus', 'quarantine', 'effect'],
#  ['eighth', 'case', 'coronavirus', 'confirmed', 'man', 'boston', 'diagnosed'],
#  ['china',
#   'isolation',
#   'continues',
#   'coronavirus',
#   'death',
#   'toll',
#   'reaches'],
#  ['bournemouth',
#   'fans',
#   'ridiculed',
#   'wearing',
#   'club',
#   'branded',
#   'coronavirus',
#   'face',
#   'masks'],
#  ['worried',
#   'chinese',
#   'tourists',
#   'face',
#   'masks',
#   'visit',
#   'windsor',
#   'castle'],
#  ['china',
#   'outbreak',
#   'forces',
#   'hyundai',
#   'suspend',
#   'flagship',
#   'suv',
#   'production'],
#  ['scientists',
#   'warn',
#   'evidence',
#   'dettol',
#   'kill',
#   'deadly',
#   'wuhan',
#   'coronavirus'],
#  ['facebook',
#   'remove',
#   'content',
#   'spreading',
#   'false',
#   'information',
#   'coronavirus'],
#  ['british',
#   'family',
#   'stranded',
#   'wuhan',
#   'four',
#   'week',
#   'old',
#   'baby',
#   'say',
#   'food',
#   'running'],
#  ['quarantined', 'brits', 'allowed', 'outside', 'anti', 'coronavirus'],
#  ['china',
#   'asks',
#   'eu',
#   'medicine',
#   'supplies',
#   'battle',
#   'coronavirus',
#   'outbreak'],
#  ['x',
#   'rays',
#   'show',
#   'effect',
#   'killer',
#   'virus',
#   'year',
#   'old',
#   'vital',
#   'organs'],
#  ['former',
#   'patient',
#   'unit',
#   'two',
#   'people',
#   'treated',
#   'coronavirus',
#   'says',
#   'felt',
#   'like',
#   'et'],
#  ['china', 'repatriates', 'citizens', 'wuhan', 'coronavirus', 'lockdown'],
#  ['coronavirus', 'panic', 'london', 'paddington', 'station', 'staff', 'masks'],
#  ['foreign', 'office', 'pulls', 'remaining', 'staff', 'china'],
#  ['australian',
#   'family',
#   'coronavirus',
#   'epicentre',
#   'wuhan',
#   'china',
#   'refuse',
#   'come',
#   'back',
#   'home'],
#  ['chinese',
#   'couple',
#   'italy',
#   'tested',
#   'positive',
#   'coronavirus',
#   'went',
#   'tour',
#   'country'],
#  ['travel',
#   'bans',
#   'plunge',
#   'china',
#   'deepening',
#   'isolation',
#   'coronavirus'],
#  ['outlier',
#   'victim',
#   'profiles',
#   'raise',
#   'questions',
#   'impact',
#   'coronavirus'],
#  ['coronavirus',
#   'misinformation',
#   'spreads',
#   'social',
#   'media',
#   'facebook',
#   'removes',
#   'posts'],
#  ['york',
#   'university',
#   'confirms',
#   'student',
#   'one',
#   'two',
#   'uk',
#   'coronavirus',
#   'cases',
#   'video'],
#  ['british',
#   'mother',
#   'describes',
#   'life',
#   'changingly',
#   'awful',
#   'evacuation',
#   'wuhan',
#   'son'],
#  ['coronavirus',
#   'quarantine',
#   'effect',
#   'us',
#   'confirms',
#   'th',
#   'case',
#   'virus',
#   'person',
#   'travelled',
#   'china'],
#  ['u', 'confirms', 'th', 'case', 'coronavirus', 'quarantine', 'effect'],
#  ['american', 'airlines', 'pilots', 'sue', 'halt', 'flights', 'china'],
#  ['pentagon',
#   'provide',
#   'housing',
#   'support',
#   'people',
#   'may',
#   'need',
#   'quarantined'],
#  ['u', 'confirms', 'eighth', 'case', 'coronavirus', 'quarantine', 'effect'],
#  ['pentagon', 'provide', 'housing', 'people', 'coronavirus', 'concerns'],
#  ['russia', 'suspends', 'visa', 'free', 'tourist', 'travel', 'china', 'virus'],
#  ['china', 'isolation', 'world', 'grows', 'virus', 'toll', 'reaches'],
#  ['coronavirus', 'media', 'hyping', 'threat'],
#  ['coronavirus',
#   'cdc',
#   'issues',
#   'unprecedented',
#   'federal',
#   'quarantine',
#   'americans',
#   'returning',
#   'wuhan',
#   'us',
#   'airlines',
#   'halt',
#   'china',
#   'flights'],
#  ['bit', 'unsettled', 'york', 'students', 'alert', 'coronavirus', 'case'],
#  ['simpsons', 'also', 'predict', 'coronavirus'],
#  ['russia', 'suspends', 'visa', 'free', 'tourist', 'travel', 'china', 'virus'],
#  ['conspiracy',
#   'theorists',
#   'telling',
#   'people',
#   'drink',
#   'dangerous',
#   'bleach',
#   'solution',
#   'cure',
#   'prevent',
#   'coronavirus'],
#  ['apple',
#   'temporarily',
#   'closes',
#   'stores',
#   'china',
#   'coronavirus',
#   'spreads'],
#  ['coronavirus', 'apple', 'closes', 'stores', 'china', 'amid', 'outbreak'],
#  ['apple',
#   'store',
#   'closings',
#   'china',
#   'could',
#   'delay',
#   'million',
#   'iphone',
#   'sales',
#   'wedbush',
#   'says'],
#  ['china', 'facing', 'global', 'isolation', 'virus', 'toll', 'rises'],
#  ['student',
#   'university',
#   'massachusetts',
#   'boston',
#   'confirmed',
#   'th',
#   'person',
#   'us',
#   'wuhan',
#   'coronavirus',
#   'trip',
#   'china'],
#  ['boston',
#   'reports',
#   'state',
#   'first',
#   'confirmed',
#   'case',
#   'coronavirus',
#   'man',
#   'placed',
#   'isolation'],
#  ['people',
#   'resort',
#   'using',
#   'bras',
#   'grapefruit',
#   'mask',
#   'really',
#   'protect',
#   'coronavirus'],
#  ['uc',
#   'berkeley',
#   'faces',
#   'backlash',
#   'stating',
#   'xenophobia',
#   'common',
#   'normal',
#   'reaction',
#   'coronavirus'],
#  ['coronavirus',
#   'deaths',
#   'new',
#   'cases',
#   'reported',
#   'hubei',
#   'province',
#   'epicentre',
#   'outbreak'],
#  ['britain', 'europe', 'trump', 'set', 'acquittal', 'weekend', 'reads'],
#  ['medical',
#   'surveillance',
#   'system',
#   'china',
#   'implemented',
#   'sars',
#   'led',
#   'officials',
#   'discover',
#   'novel',
#   'coronavirus',
#   'within',
#   'week',
#   'works'],
#  ['coronavirus',
#   'decision',
#   'ban',
#   'new',
#   'visitors',
#   'china',
#   'protect',
#   'singapore',
#   'public',
#   'health',
#   'pm',
#   'lee',
#   'says'],
#  ['asia',
#   'gold',
#   'demand',
#   'slumps',
#   'coronavirus',
#   'grips',
#   'top',
#   'consumer'],
#  ['michelle',
#   'phan',
#   'says',
#   'targeted',
#   'racism',
#   'amid',
#   'wuhan',
#   'coronavirus',
#   'scare',
#   'telling',
#   'go',
#   'back',
#   'eating',
#   'bats',
#   'american',
#   'ignorant',
#   'f'],
#  ['china', 'hubei', 'province', 'reports', 'rise', 'coronavirus', 'deaths'],
#  ['britons', 'evacuated', 'wuhan', 'china', 'sunday', 'liverpool', 'echo'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'china',
#   'hubei',
#   'province',
#   'confirms',
#   'additional',
#   'deaths',
#   'cases'],
#  ['china', 'virus', 'death', 'toll', 'rises', 'new', 'fatalities', 'govt'],
#  ['north', 'korea', 'coronavirus', 'comes', 'shores'],
#  ['quarantines',
#   'await',
#   'europeans',
#   'flown',
#   'home',
#   'amid',
#   'virus',
#   'outbreak'],
#  ['china', 'coronavirus', 'toll', 'reaches', 'number', 'cases', 'hits'],
#  ['british', 'coronavirus', 'evacuees', 'left', 'behind', 'rescued'],
#  ['male',
#   'chinese',
#   'student',
#   'mother',
#   'uk',
#   'first',
#   'coronavirus',
#   'victims'],
#  ['watch',
#   'u',
#   'citizens',
#   'document',
#   'like',
#   'live',
#   'wuhan',
#   'coronavirus',
#   'lockdown'],
#  ['wuhan',
#   'woman',
#   'screams',
#   'chinese',
#   'authorities',
#   'barricade',
#   'inside',
#   'home'],
#  ['uber',
#   'suspends',
#   'accounts',
#   'mexico',
#   'prevent',
#   'coronavirus',
#   'spreading'],
#  ['china', 'coronavirus', 'deaths', 'infections', 'jump', 'latest', 'updates'],
#  ['china',
#   'total',
#   'number',
#   'coronavirus',
#   'deaths',
#   'reaches',
#   'end',
#   'february'],
#  ['calls',
#   'street',
#   'cleaners',
#   'get',
#   'proper',
#   'protective',
#   'gear',
#   'rest',
#   'hong',
#   'kong',
#   'hunkers',
#   'coronavirus',
#   'storm'],
#  ['china', 'reports', 'virus', 'deaths', 'fires', 'officials', 'poor', 'job'],
#  ['china', 'virus', 'death', 'toll', 'surges', 'past'],
#  ['u',
#   'imposes',
#   'coronavirus',
#   'quarantine',
#   'group',
#   'california',
#   'evacuated',
#   'wuhan'],
#  ['china',
#   'total',
#   'number',
#   'coronavirus',
#   'deaths',
#   'reaches',
#   'end',
#   'february'],
#  ['dead', 'coronavirus', 'outbreak', 'infects'],
#  ['coronavirus',
#   'may',
#   'sprung',
#   'perfect',
#   'mixing',
#   'pot',
#   'infectious',
#   'disease',
#   'doctor',
#   'says'],
#  ['china',
#   'coronavirus',
#   'infections',
#   'hit',
#   'daily',
#   'record',
#   'deaths',
#   'climb'],
#  ['outcasts',
#   'country',
#   'people',
#   'wuhan',
#   'unwanted',
#   'faces',
#   'china',
#   'coronavirus',
#   'outbreak'],
#  ['china',
#   'coronavirus',
#   'duterte',
#   'orders',
#   'travel',
#   'ban',
#   'visitors',
#   'mainland',
#   'hong',
#   'kong',
#   'philippine',
#   'media',
#   'says'],
#  ['coronavirus', 'government', 'launches', 'public', 'health', 'campaign'],
#  ['please',
#   'take',
#   'daughter',
#   'mother',
#   'girl',
#   'cancer',
#   'pleads',
#   'virus',
#   'blockade'],
#  ['please',
#   'take',
#   'daughter',
#   'mother',
#   'girl',
#   'cancer',
#   'pleads',
#   'virus',
#   'blockade'],
#  ['dead', 'coronavirus', 'cases', 'confirmed'],
#  ['trump', 'trudeau', 'discussed', 'coronavirus', 'friday', 'phone', 'call'],
#  ['coronavirus', 'china', 'toll', 'climbs', 'confirmed', 'infections', 'top'],
#  ['xenophobia',
#   'pre',
#   'existing',
#   'condition',
#   'harmful',
#   'stereotypes',
#   'racism',
#   'spreading',
#   'around',
#   'coronavirus'],
#  ['coronavirus',
#   'hong',
#   'kong',
#   'health',
#   'workers',
#   'strike',
#   'border',
#   'row',
#   'china'],
#  ['trump', 'trudeau', 'discussed', 'coronavirus', 'friday', 'phone', 'call'],
#  ['philippine', 'carriers', 'cancel', 'flights', 'china', 'coronavirus'],
#  ['philippines',
#   'reports',
#   'first',
#   'death',
#   'outside',
#   'china',
#   'coronavirus',
#   'outbreak'],
#  ['philippines',
#   'reports',
#   'first',
#   'coronavirus',
#   'fatality',
#   'second',
#   'confirmed',
#   'infection'],
#  ['pentagon',
#   'preparing',
#   'house',
#   'people',
#   'military',
#   'sites',
#   'may',
#   'need',
#   'quarantined',
#   'due',
#   'wuhan',
#   'coronavirus',
#   'outbreak'],
#  ['philippines',
#   'reports',
#   'first',
#   'coronavirus',
#   'fatality',
#   'second',
#   'confirmed',
#   'infection'],
#  ['philippines', 'reports', 'st', 'virus', 'death', 'outside', 'china'],
#  ['health',
#   'officials',
#   'say',
#   'testing',
#   'first',
#   'possible',
#   'wuhan',
#   'coronavirus',
#   'case',
#   'new',
#   'york',
#   'city'],
#  ['coronavirus',
#   'vietnam',
#   'backtracks',
#   'hong',
#   'kong',
#   'flight',
#   'ban',
#   'restricts',
#   'travellers',
#   'mainland',
#   'china'],
#  ['vietnam', 'bans', 'flights', 'china', 'coronavirus'],
#  ['new',
#   'zealand',
#   'bar',
#   'entry',
#   'foreigners',
#   'traveling',
#   'mainland',
#   'china'],
#  ['first',
#   'death',
#   'coronavirus',
#   'outside',
#   'china',
#   'reported',
#   'philippines'],
#  ['india',
#   'reports',
#   'second',
#   'coronavirus',
#   'case',
#   'kerala',
#   'patient',
#   'stable'],
#  ['philippines',
#   'reports',
#   'first',
#   'coronavirus',
#   'death',
#   'outside',
#   'china'],
#  ['japan',
#   'confirms',
#   'three',
#   'citizens',
#   'evacuated',
#   'wuhan',
#   'test',
#   'positive',
#   'coronavirus'],
#  ['new',
#   'zealand',
#   'bar',
#   'entry',
#   'foreigners',
#   'travelling',
#   'mainland',
#   'china'],
#  ['coronavirus',
#   'update',
#   'india',
#   'reports',
#   'second',
#   'case',
#   'virus',
#   'kerala'],
#  ['vietnam', 'bans', 'flights', 'china', 'coronavirus'],
#  ['india',
#   'flies',
#   'home',
#   'citizens',
#   'chinese',
#   'city',
#   'battling',
#   'coronavirus'],
#  ['wash',
#   'hands',
#   'tokyo',
#   'governor',
#   'residents',
#   'ahead',
#   'olympics',
#   'coronavirus',
#   'spreads'],
#  ['please',
#   'take',
#   'daughter',
#   'mother',
#   'girl',
#   'cancer',
#   'pleads',
#   'virus',
#   'blockade'],
#  ['coronavirus',
#   'kills',
#   'chinese',
#   'man',
#   'philippines',
#   'first',
#   'death',
#   'outside',
#   'china'],
#  ['coronavirus',
#   'working',
#   'home',
#   'novel',
#   'occasionally',
#   'frustrating',
#   'experience',
#   'hongkongers',
#   'used',
#   'rhythms',
#   'office',
#   'life'],
#  ['coronavirus',
#   'grown',
#   'lab',
#   'outside',
#   'china',
#   'first',
#   'time',
#   'aiding',
#   'search',
#   'vaccine'],
#  ['coronavirus', 'death', 'philippines', 'said', 'first', 'outside', 'china'],
#  ['saudi',
#   'arabia',
#   'evacuates',
#   'students',
#   'china',
#   'wuhan',
#   'saudi',
#   'state',
#   'tv'],
#  ['taiwan',
#   'scrambles',
#   'diplomats',
#   'keep',
#   'flights',
#   'going',
#   'amid',
#   'china',
#   'virus',
#   'inclusion'],
#  ['wash',
#   'hands',
#   'tokyo',
#   'governor',
#   'residents',
#   'ahead',
#   'olympics',
#   'coronavirus',
#   'spreads'],
#  ['coronavirus',
#   'live',
#   'updates',
#   'air',
#   'india',
#   'nd',
#   'flight',
#   'lands',
#   'delhi',
#   'indians'],
#  ['hong',
#   'kong',
#   'set',
#   'roll',
#   'measures',
#   'residents',
#   'going',
#   'mainland',
#   'china',
#   'government',
#   'adviser',
#   'says',
#   'warning',
#   'public',
#   'cross',
#   'border',
#   'unless',
#   'absolutely',
#   'necessary'],
#  ['coronavirus',
#   'kills',
#   'chinese',
#   'man',
#   'philippines',
#   'first',
#   'death',
#   'outside',
#   'china'],
#  ['fears',
#   'new',
#   'virus',
#   'trigger',
#   'anti',
#   'china',
#   'sentiment',
#   'worldwide'],
#  ['u',
#   'military',
#   'korea',
#   'imposes',
#   'quarantine',
#   'troops',
#   'returning',
#   'china'],
#  ['coronavirus',
#   'new',
#   'zealand',
#   'bar',
#   'entry',
#   'foreigners',
#   'travelling',
#   'mainland',
#   'china'],
#  ['philippines',
#   'reports',
#   'first',
#   'case',
#   'coronavirus',
#   'death',
#   'outside',
#   'china'],
#  ['new',
#   'zealand',
#   'bar',
#   'entry',
#   'foreigners',
#   'traveling',
#   'mainland',
#   'china'],
#  ['china',
#   'says',
#   'wuhan',
#   'coronavirus',
#   'victims',
#   'die',
#   'quickly',
#   'cremated',
#   'without',
#   'funerals',
#   'death',
#   'toll',
#   'rises'],
#  ['india',
#   'reports',
#   'second',
#   'case',
#   'coronavirus',
#   'southern',
#   'state',
#   'kerala'],
#  ['coronavirus',
#   'update',
#   'second',
#   'confirmed',
#   'patient',
#   'reported',
#   'kerala'],
#  ['coronavirus',
#   'outbreak',
#   'halts',
#   'meeting',
#   'top',
#   'china',
#   'economists',
#   'vice',
#   'premier',
#   'liu'],
#  ['philippines', 'reports', 'first', 'virus', 'death', 'outside', 'china'],
#  ['u',
#   'military',
#   'south',
#   'korea',
#   'imposes',
#   'quarantine',
#   'troops',
#   'returning',
#   'china'],
#  ['coronavirus', 'scary', 'flu', 'deadlier', 'widespread'],
#  ['saudi',
#   'arabia',
#   'evacuates',
#   'students',
#   'china',
#   'wuhan',
#   'saudi',
#   'state',
#   'tv'],
#  ['escaping',
#   'virus',
#   'lockdown',
#   'wuhan',
#   'would',
#   'torn',
#   'family',
#   'stayed'],
#  ['coronavirus',
#   'spreads',
#   'tsa',
#   'issues',
#   'new',
#   'directive',
#   'anyone',
#   'entering',
#   'us',
#   'china'],
#  ['hong',
#   'kong',
#   'largest',
#   'quarantine',
#   'site',
#   'homes',
#   'ready',
#   'one',
#   'two',
#   'months',
#   'sources',
#   'say',
#   'city',
#   'remains',
#   'grip',
#   'coronavirus',
#   'outbreak'],
#  ['brace',
#   'volatility',
#   'budget',
#   'hangover',
#   'coronavirus',
#   'keeps',
#   'markets',
#   'edge'],
#  ['korea',
#   'bar',
#   'people',
#   'visited',
#   'virus',
#   'hit',
#   'province',
#   'china',
#   'yonhap'],
#  ['escaping',
#   'virus',
#   'lockdown',
#   'wuhan',
#   'would',
#   'torn',
#   'family',
#   'stayed'],
#  ['china',
#   'must',
#   'outlaw',
#   'trade',
#   'consumption',
#   'exotic',
#   'animals',
#   'protect',
#   'endangered',
#   'species',
#   'also',
#   'health',
#   'mankind'],
#  ['philippines',
#   'races',
#   'trace',
#   'linked',
#   'first',
#   'coronavirus',
#   'death',
#   'outside',
#   'china'],
#  ['country',
#   'second',
#   'case',
#   'coronavirus',
#   'reported',
#   'kerala',
#   'patient',
#   'isolated'],
#  ['south',
#   'korea',
#   'bar',
#   'people',
#   'visited',
#   'virus',
#   'hit',
#   'province',
#   'china',
#   'yonhap'],
#  ['kazakhstan', 'evacuates', 'citizens', 'china', 'wuhan'],
#  ['soccer',
#   'australia',
#   'seek',
#   'urgent',
#   'reshuffling',
#   'champions',
#   'league',
#   'matches'],
#  ['coronavirus',
#   'hospital',
#   'workers',
#   'group',
#   'cancels',
#   'meeting',
#   'authority',
#   'ahead',
#   'strike',
#   'hong',
#   'kong',
#   'leader',
#   'carrie',
#   'lam',
#   'refuses',
#   'take',
#   'part',
#   'dialogue'],
#  ['philippines',
#   'records',
#   'first',
#   'coronavirus',
#   'death',
#   'number',
#   'killed',
#   'china',
#   'rises',
#   'hours'],
#  ['kazakhstan', 'evacuates', 'citizens', 'china', 'wuhan'],
#  ['australia',
#   'seek',
#   'urgent',
#   'reshuffling',
#   'champions',
#   'league',
#   'matches'],
#  ['coronavirus',
#   'qantas',
#   'flight',
#   'leaves',
#   'sydney',
#   'evacuate',
#   'australians',
#   'stuck',
#   'china'],
#  ['oman',
#   'saudi',
#   'state',
#   'airline',
#   'saudia',
#   'suspend',
#   'flights',
#   'china',
#   'virus'],
#  ...]

# %%
model = Word2Vec(corpus, size=100, min_count=1)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 85390 words, keeping 8357 word types
# PROGRESS: at sentence #20000, processed 168698 words, keeping 12104 word types
# PROGRESS: at sentence #30000, processed 250568 words, keeping 15077 word types
# PROGRESS: at sentence #40000, processed 333508 words, keeping 17739 word types
# PROGRESS: at sentence #50000, processed 417802 words, keeping 20054 word types
# PROGRESS: at sentence #60000, processed 502255 words, keeping 22136 word types
# PROGRESS: at sentence #70000, processed 587489 words, keeping 23953 word types
# PROGRESS: at sentence #80000, processed 672141 words, keeping 25530 word types
# PROGRESS: at sentence #90000, processed 756843 words, keeping 26976 word types
# PROGRESS: at sentence #100000, processed 841520 words, keeping 28343 word types
# PROGRESS: at sentence #110000, processed 926732 words, keeping 29602 word types
# PROGRESS: at sentence #120000, processed 1011361 words, keeping 30720 word types
# PROGRESS: at sentence #130000, processed 1095911 words, keeping 31925 word types
# PROGRESS: at sentence #140000, processed 1179802 words, keeping 33015 word types
# PROGRESS: at sentence #150000, processed 1263720 words, keeping 34040 word types
# PROGRESS: at sentence #160000, processed 1347859 words, keeping 35018 word types
# collected 35175 word types from a corpus of 1362019 raw words and 161654 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 35175 unique words (100% of original 35175, drops 0)
# effective_min_count=1 leaves 1362019 word corpus (100% of original 1362019, drops 0)
# deleting the raw counts dictionary of 35175 items
# sample=0.001 downsamples 25 most-common words
# downsampling leaves estimated 1212350 word corpus (89.0% of prior 1362019)
# estimated required memory for 35175 words and 100 dimensions: 45727500 bytes
# resetting layer weights
# training model with 3 workers on 35175 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# EPOCH 1 - PROGRESS: at 36.20% examples, 427501 words/s, in_qsize 5, out_qsize 0
# EPOCH 1 - PROGRESS: at 71.18% examples, 421522 words/s, in_qsize 5, out_qsize 0
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 1362019 raw words (1212260 effective words) took 2.7s, 455213 effective words/s
# EPOCH 2 - PROGRESS: at 45.66% examples, 544133 words/s, in_qsize 5, out_qsize 0
# EPOCH 2 - PROGRESS: at 92.47% examples, 557385 words/s, in_qsize 5, out_qsize 0
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 1362019 raw words (1212737 effective words) took 2.2s, 558160 effective words/s
# EPOCH 3 - PROGRESS: at 58.81% examples, 705609 words/s, in_qsize 5, out_qsize 0
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 1362019 raw words (1212443 effective words) took 1.8s, 691565 effective words/s
# EPOCH 4 - PROGRESS: at 41.28% examples, 491953 words/s, in_qsize 6, out_qsize 0
# EPOCH 4 - PROGRESS: at 76.29% examples, 454958 words/s, in_qsize 5, out_qsize 0
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 1362019 raw words (1212465 effective words) took 2.6s, 463346 effective words/s
# EPOCH 5 - PROGRESS: at 40.55% examples, 476619 words/s, in_qsize 5, out_qsize 0
# EPOCH 5 - PROGRESS: at 82.86% examples, 496827 words/s, in_qsize 5, out_qsize 0
# worker thread finished; awaiting finish of 2 more threads
# worker thread finished; awaiting finish of 1 more threads
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 1362019 raw words (1212490 effective words) took 2.4s, 499991 effective words/s
# training on a 6810095 raw words (6062395 effective words) took 11.8s, 514583 effective words/s

# %%
# fit a 2D PCA model to the vectors
vectors = model[model.wv.vocab]
words = list(model.wv.vocab)
pca = PCA(n_components=2)
PCA_result = pca.fit_transform(vectors)
# Out:
# <ipython-input-7-ff79d471002d>:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   vectors = model[model.wv.vocab]

# %%
# prepare a dataframe
words = pd.DataFrame(words)
PCA_result = pd.DataFrame(PCA_result)
PCA_result['x_values'] =PCA_result.iloc[0:, 0]
PCA_result['y_values'] =PCA_result.iloc[0:, 1]
PCA_final = pd.merge(words, PCA_result, left_index=True, right_index=True)
PCA_final['word'] =PCA_final.iloc[0:, 0]
PCA_data_complet =PCA_final[['word','x_values','y_values']]
PCA_data_complet.to_csv('PCA_data_complet.csv',index=False)

# %%
print(PCA_data_complet)
# Out:
#               word  x_values  y_values
# 0          british  2.523623  1.836101
# 1      coronavirus  2.056741 -0.672322
# 2          evacuee  0.525597  0.406559
# 3            taken  1.963146  1.201577
# 4              ill  2.184186  2.426750
# ...            ...       ...       ...
# 35170    masterjee -0.517581 -0.025725
# 35171     netizens -0.514347 -0.050055
# 35172     untraced -0.598825 -0.076903
# 35173      furough -0.539792 -0.037048
# 35174  explosively -0.521675 -0.076559
#
# [35175 rows x 3 columns]

# %%
# word frequencies calculation
from collections import Counter
# count unique words
def counter_word(text_col):
    count = Counter()
    for text in text_col.values:
        for word in text.split():
            count[word] += 1
    return count

counter_all = counter_word(data.title)
words_all = counter_all.most_common(100)

words_all= pd.DataFrame(words_all)
words_all['word'] = words_all.iloc[0:, 0]
words_all['count'] = words_all.iloc[0:, 1]
words_all = words_all[['word','count']]
words_all.to_csv('top100_words.csv', columns=['word','count'], index=False)

# %%
# restriction to 100 most frequent words
top100_words = pd.read_csv('top100_words.csv')
PCA_data_top_100 = PCA_data_complet.merge(top100_words, how='inner', left_on='word',right_on='word')
PCA_data_top_100.to_csv('PCA_data_top_100.csv', index=False)

# %%
# K-means cluster visualisation
K_means_data = pd.read_excel('K-means_clustering.xlsx')

sns.set_style('ticks')
fig = sns.lmplot(x='x_values', y='y_values',
           data = K_means_data,
           fit_reg=False,
           legend=True,
           hue='Cluster')
fig = plt.gcf()
fig.set_size_inches(8, 6)

plt.savefig('word2vec_clustering.png')

plt.show()

# %%
K_means_data
# Out:
#     x_values  y_values   count Selected         word Cluster  Silhouette  \
# 0   2.114283 -0.601364  101954       No  coronavirus      C3    0.500000
# 1   2.701490 -0.471515    1627       No        wuhan      C8    0.493042
# 2   3.716232 -3.177167    1511       No    emergency      C6    0.592801
# 3   2.604488  0.994713    2819       No         test      C4    0.579329
# 4   3.222806 -1.000762    2132       No         face      C8    0.620955
# ..       ...       ...     ...      ...          ...     ...         ...
# 95  3.978523 -4.784225    1962       No         rise      C5    0.639390
# 96  4.510755  2.439026    1504       No        boris      C7    0.618911
# 97  4.282936 -4.727693    1697       No       reopen      C5    0.664938
# 98  3.357510 -4.645325    1589       No       states      C6    0.619798
# 99  2.309909 -1.281616   18510       No        covid      C1    0.543681
#
#    Selected (1) Selected (2)
# 0            No           No
# 1            No           No
# 2            No           No
# 3            No           No
# 4            No           No
# ..          ...          ...
# 95           No           No
# 96           No           No
# 97           No           No
# 98           No           No
# 99           No           No
#
# [100 rows x 9 columns]
